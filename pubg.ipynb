# %% [markdown]
# # PUBG deaths visualization

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go

from alive_progress import alive_bar

# %%
agg_data_files = ["aggregate/agg_match_stats_0.csv", "aggregate/agg_match_stats_1.csv",
                  "aggregate/agg_match_stats_2.csv", "aggregate/agg_match_stats_3.csv",
                  "aggregate/agg_match_stats_4.csv"]

deaths_data_files = ["deaths/kill_match_stats_final_0.csv", "deaths/kill_match_stats_final_1.csv",
                    "deaths/kill_match_stats_final_2.csv", "deaths/kill_match_stats_final_3.csv",
                    "deaths/kill_match_stats_final_4.csv"]

miramar = "miramar.jpg"
erangel = "erangel.jpg"

# %%
agg_df = pd.read_csv(agg_data_files[0], nrows=10000)
kill_df = pd.read_csv(deaths_data_files[0], nrows=10000)

# %%
agg_df.head()
# Out:
#                        date  game_size  \
# 0  2017-11-26T20:59:40+0000         37
# 1  2017-11-26T20:59:40+0000         37
# 2  2017-11-26T20:59:40+0000         37
# 3  2017-11-26T20:59:40+0000         37
# 4  2017-11-26T20:59:40+0000         37
#
#                                             match_id match_mode  party_size  \
# 0  2U4GBNA0YmnNZYkzjkfgN4ev-hXSrak_BSey_YEG6kIuDG...        tpp           2
# 1  2U4GBNA0YmnNZYkzjkfgN4ev-hXSrak_BSey_YEG6kIuDG...        tpp           2
# 2  2U4GBNA0YmnNZYkzjkfgN4ev-hXSrak_BSey_YEG6kIuDG...        tpp           2
# 3  2U4GBNA0YmnNZYkzjkfgN4ev-hXSrak_BSey_YEG6kIuDG...        tpp           2
# 4  2U4GBNA0YmnNZYkzjkfgN4ev-hXSrak_BSey_YEG6kIuDG...        tpp           2
#
#    player_assists  player_dbno  player_dist_ride  player_dist_walk  \
# 0               0            1        2870.72400       1784.847780
# 1               0            1        2938.40723       1756.079710
# ...

# %%
kill_df.head()
# Out:
#       killed_by       killer_name  killer_placement  killer_position_x  \
# 0       Grenade   KrazyPortuguese               5.0          657725.10
# 1        SCAR-L  nide2Bxiaojiejie              31.0           93091.37
# 2          S686          Ascholes              43.0          366921.40
# 3  Down and Out        Weirdo7777               9.0          472014.20
# 4          M416         Solayuki1               9.0          473357.80
#
#    killer_position_y      map  \
# 0           146275.2  MIRAMAR
# 1           722236.4  MIRAMAR
# 2           421623.9  MIRAMAR
# 3           313274.8  MIRAMAR
# 4           318340.5  MIRAMAR
#
#                                             match_id  time      victim_name  \
# 0  2U4GBNA0YmnLSqvEycnTjo-KT000vfUnhSA2vfVhVPe1QB...   823  KrazyPortuguese
# 1  2U4GBNA0YmnLSqvEycnTjo-KT000vfUnhSA2vfVhVPe1QB...   194      X3evolution
# 2  2U4GBNA0YmnLSqvEycnTjo-KT000vfUnhSA2vfVhVPe1QB...   103          CtrlZee
# ...

# %% [markdown]
# ## Plot map image in `Plotly`

# %%
from PIL import Image

im = Image.open(miramar)
width, height = im.size
print(width,height)
# Out:
# 1000 1000

# %%
from IPython.display import Image

Image(filename=miramar)

# %% [markdown]
# ## Normalize coordinates in `kill_df`

# %%
# killer coordinates
kill_df['killer_position_x'] = kill_df.killer_position_x/800000*1000
kill_df['killer_position_y'] = kill_df.killer_position_y/800000*1000

# victim coordinates
kill_df['victim_position_x'] = kill_df.victim_position_x/800000*1000
kill_df['victim_position_y'] = kill_df.victim_position_y/800000*1000

# %% [markdown]
# ## Interactive animated plot for one game

# %%
kill_df.match_id.unique()[0]
# Out:
# '2U4GBNA0YmnLSqvEycnTjo-KT000vfUnhSA2vfVhVPe1QBwCTNTBJ5B_1Ocel6nY'

# %%
one_game_df = kill_df[(kill_df['match_id'] == kill_df.match_id.unique()[0]) |\
                      (kill_df['match_id'] == kill_df.match_id.unique()[1]) |\
                      (kill_df['match_id'] == kill_df.match_id.unique()[2]) |\
                      (kill_df['match_id'] == kill_df.match_id.unique()[3]) |\
                      (kill_df['match_id'] == kill_df.match_id.unique()[4])].sort_values('time')

# %%
one_game_df['kill_range'] = np.sqrt((one_game_df.killer_position_x - one_game_df.victim_position_x)**2 +\
                                    (one_game_df.killer_position_y - one_game_df.victim_position_y)**2)

# %%
one_game_df
# Out:
#     killed_by   killer_name  killer_placement  killer_position_x  \
# 241   Mini 14    mrsparkles              46.0         561.583250
# 99        SKS    QuY-BeO---              22.0         545.163875
# 135       AKM      #unknown              20.0         542.466000
# 238    SCAR-L          UGAT              41.0         570.499000
# 212   Mini 14        B0nD0k              37.0         558.601750
# ..        ...           ...               ...                ...
# 189      M416      AlooGobi               2.0         628.925875
# 218      M416  DevilBlood35               1.0         631.141875
# 87       M416  DouYuTV-SeaL               1.0         708.659500
# 55    Grenade       MeLeeXH               1.0         710.058875
# 46       M416  DouYuTV-SeaL               1.0         708.811500
#
#      killer_position_y      map  \
# 241         776.976625  ERANGEL
# 99          351.123250  MIRAMAR
# 135         348.606000  MIRAMAR
# 238         783.843875  ERANGEL
# ...

# %%
def set_kill_range_cat(x):
    if x <= 1.25:
        return "short"
    elif x > 1.25 and x <= 2.5:
        return "mid"
    elif x > 2.5 and x <= 12.5:
        return "long"
    else:
        return "extra long"

# %%
one_game_df['kill_range_cat'] = one_game_df.kill_range.apply(set_kill_range_cat)
one_game_df
# Out:
#     killed_by   killer_name  killer_placement  killer_position_x  \
# 241   Mini 14    mrsparkles              46.0         561.583250
# 99        SKS    QuY-BeO---              22.0         545.163875
# 135       AKM      #unknown              20.0         542.466000
# 238    SCAR-L          UGAT              41.0         570.499000
# 212   Mini 14        B0nD0k              37.0         558.601750
# ..        ...           ...               ...                ...
# 189      M416      AlooGobi               2.0         628.925875
# 218      M416  DevilBlood35               1.0         631.141875
# 87       M416  DouYuTV-SeaL               1.0         708.659500
# 55    Grenade       MeLeeXH               1.0         710.058875
# 46       M416  DouYuTV-SeaL               1.0         708.811500
#
#      killer_position_y      map  \
# 241         776.976625  ERANGEL
# 99          351.123250  MIRAMAR
# 135         348.606000  MIRAMAR
# 238         783.843875  ERANGEL
# ...

# %%
trace1 = go.Scatter(x=one_game_df.killer_position_x,
                    y=abs(one_game_df.killer_position_y-1000),
                    mode='markers',
                    marker=dict(size=5, color='blue'))

trace2 = go.Scatter(x = one_game_df.victim_position_x,
                    y = abs(one_game_df.victim_position_y-1000),
                    mode='markers',
                    text= one_game_df.victim_name,
                    marker_size= 5,
                    marker_color= 'rgba(255,0,255, 0.7)',
                    marker_colorscale= [])

frames = [dict(data= [dict(type='scatter',
                           x=one_game_df.killer_position_x[:k+1],
                           y=abs(one_game_df.killer_position_y[:k+1]-1000)),
                      dict(type='scatter',
                           x=one_game_df.victim_position_x[:k+1],
                           y=abs(one_game_df.victim_position_y[:k+1]-1000))],
               traces= [0, 1],  #this means that  frames[k]['data'][0]  updates trace1, and   frames[k]['data'][1], trace2 
              )for k  in  range(1, len(one_game_df.killer_position_y.to_list())-1)]

layout = go.Layout(width=800,
                   height=800,
                   showlegend=False,
                   hovermode='closest',
                   updatemenus=[dict(type='buttons', showactive=False,
                                y=1.05,
                                x=1.15,
                                xanchor='right',
                                yanchor='top',
                                pad=dict(t=0, r=10),
                                buttons=[dict(label='Play',
                                              method='animate',
                                              args=[None, 
                                                    dict(frame=dict(duration=10, 
                                                                    redraw=False),
                                                         transition=dict(duration=10),
                                                         fromcurrent=True,
                                                         mode='immediate')]),
                                    
                                        dict(label='Pause',
                                               method='relayout',
                                               args=[None, 
                                                     dict(frame=dict(duration=0, 
                                                                     redraw=False),
                                                          transition=dict(duration=0),
                                                          fromcurrent=True,
                                                          mode='immediate')])])])


layout.update(xaxis =dict(range=[0, 1000], autorange=False),
              yaxis =dict(range=[0, 1000], autorange=False));
fig = go.Figure(data=[trace2], frames=frames, layout=layout)
fig.add_layout_image(
        source=miramar,
        xref="paper",
        yref="paper",
        x=0,
        y=1,
        xanchor="left",
        yanchor="top",
        layer="below",
        sizing="stretch",
        sizex=1.0,
        sizey=1.0
    )

fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [52], in <module>
#       2 d = dict(zip(u_states, np.arange(len(u_states))))
#       4 trace1 = go.Scatter(x=one_game_df.killer_position_x,
#       5                     y=abs(one_game_df.killer_position_y-1000),
#       6                     mode='markers',
#       7                     marker=dict(size=5, color='blue'))
# ----> 9 trace2 = go.Scatter(x = one_game_df.victim_position_x,
#      10                     y = abs(one_game_df.victim_position_y-1000),
#      11                     color = one_game_df.kill_range_cat,
#      12                     mode='markers',
#      13                     text= one_game_df.victim_name,
#      14                     marker_size= 5,
#      15                     marker_color= [d[s] for s in one_game_df['kill_range_cat']])
#      17 frames = [dict(data= [dict(type='scatter',
# ...
